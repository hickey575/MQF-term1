# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from matplotlib import pyplot as plt

# %%
data1 = pd.read_csv("corpfund.csv")

# %%
data1
# Out:
#        ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0           A       ARQ   2010-03-31  2010-06-07   2010-04-30  2020-09-01
# 1           A       ARQ   2010-06-30  2010-09-07   2010-07-31  2020-09-01
# 2           A       ARQ   2010-09-30  2010-12-20   2010-10-31  2020-09-01
# 3           A       ARQ   2010-12-31  2011-03-09   2011-01-31  2020-09-01
# 4           A       ARQ   2011-03-31  2011-06-07   2011-04-30  2020-09-01
# ...       ...       ...          ...         ...          ...         ...
# 972144   SPRB       MRT   2018-12-31  2018-12-31   2018-12-31  2020-10-09
# 972145   SPRB       MRT   2019-12-31  2019-12-31   2019-12-31  2020-10-09
# 972146   SPRB       MRT   2020-06-30  2020-06-30   2020-06-30  2020-10-09
# 972147   SPRB       MRY   2018-12-31  2018-12-31   2018-12-31  2020-10-09
# 972148   SPRB       MRY   2019-12-31  2019-12-31   2019-12-31  2020-10-09
#
#              accoci        assets  assetsavg       assetsc  ...    sharesbas  \
# ...

# %%
data2 = pd.read_csv("stockmetadata.csv")
data2
# Out:
#       Unnamed: 0 table  permaticker ticker  \
# 0              0   SF1       196290      A
# 1              1   SF1       124392     AA
# 2             10   SF1       189031   AACG
# 3             11   SF1       187592   AACH
# 4             13   SF1       631654   AACQ
# ...          ...   ...          ...    ...
# 5593       15053   SF1       195000    ZVO
# 5594       15056   SF1       165622  ZXAIY
# 5595       15057   SF1       123153   ZYME
# 5596       15058   SF1       157146   ZYNE
# 5597       15060   SF1       198130   ZYXI
#
#                                     name exchange isdelisted  \
# 0               Agilent Technologies Inc     NYSE          N
# 1                             Alcoa Corp     NYSE          N
# 2                  ATA Creativity Global   NASDAQ          N
# 3                       AAC Holdings Inc      OTC          N
# 4                 Artius Acquisition Inc   NASDAQ          N
# ...                                  ...      ...        ...
# ...
